# %%
options(repr.plot.res = 300)

# %%
library(ggplot2)

# %%
ggplot() +
    geom_point(aes(x=c(1,2,3,4), y=c(1,2,3,4)))
# Out:
# plot without title

# %%
options()
# Out:
# $add.smooth
# [1] TRUE
#
# $bitmapType
# [1] "cairo"
#
# $browser
# [1] "xdg-open"
#
# $browserNLdisabled
# [1] FALSE
#
# $callr.condition_handler_cli_message
# function (msg)
# {
#     custom_handler <- getOption("cli.default_handler")
#     if (is.function(custom_handler)) {
#         custom_handler(msg)
#     }
#     else {
#         cli_server_default(msg)
#     }
# }
# <bytecode: 0x57e8b5034830>
# <environment: namespace:cli>
#
# $CBoundsCheck
# [1] FALSE
#
# $check.bounds
# [1] FALSE
#
# $citation.bibtex.max
# [1] 1
#
# $continue
# [1] "+ "
#
# $contrasts
#         unordered           ordered
# "contr.treatment"      "contr.poly"
#
# $crayon.enabled
# [1] TRUE
#
# $defaultPackages
# [1] "datasets"  "utils"     "grDevices" "graphics"  "stats"     "methods"
#
# $demo.ask
# [1] "default"
#
# $deparse.cutoff
# [1] 60
#
# $device
# function (filename = null_filename, ...)
# ok_device(filename, ...)
# <bytecode: 0x57e8b24930c8>
# <environment: 0x57e8b2481158>
#
# $device.ask.default
# ...
